# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 724.4 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.7/793.7 kB 6.5 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/kaggle/input/kecilin/data.yaml epochs=200 imgsz=640 batch=25 verbose=True
# Out:
# ...
# 100%|███████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 170MB/s]
# Ultralytics YOLOv8.2.46 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...
